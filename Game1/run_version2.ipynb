# %%
# %reload_ext autoreload
# %autoreload 2
import logging
import grpc
import pandas as pd
import sys
sys.path.append('proto')
from proto import contest_pb2
from proto import contest_pb2_grpc
from proto import question_pb2
from proto import question_pb2_grpc
import numpy as np
import time
from utils import *
from strategy_utils import *

# %%
import lightgbm as lgb
import joblib

import keras
from keras.models import load_model

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config))

lgb_model = joblib.load('./lgb_model.pkl')
k_model = load_model('dnn_overfit2.h5')

# %%
df = pd.read_csv('./data/saved_data.csv',dtype=float).set_index(['date','asset'])
o = df['open'].unstack(level=1).values
h = df['high'].unstack(level=1).values
l = df['low'].unstack(level=1).values
c = df['close'].unstack(level=1).values
v = df['volume'].unstack(level=1).values
r = df['close'].unstack(level=1).pct_change().values

dailyfactors = get_factors_with_ohlcv(o,h,l,c,v,lgb_model,k_model)

# %%
history_weights = np.empty((0,dailyfactors.shape[1],dailyfactors.shape[0]))
for j in range(52,0,-1):
    dailyfactors = get_factors_with_ohlcv(o[-j-252:-j],h[-j-252:-j],l[-j-252:-j],c[-j-252:-j],v[-j-252:-j],lgb_model,k_model)
    daily_factor_weights = get_all_weights(dailyfactors,head_n=10,tail_n=10)
    history_weights = np.vstack([history_weights,daily_factor_weights.reshape((1,daily_factor_weights.shape[0],daily_factor_weights.shape[1]))])
dailyfactors = get_factors_with_ohlcv(o[-252:],h[-252:],l[-252:],c[-252:],v[-252:],lgb_model,k_model)
daily_factor_weights = get_all_weights(dailyfactors,head_n=10,tail_n=10)
history_weights = np.vstack([history_weights,daily_factor_weights.reshape((1,daily_factor_weights.shape[0],daily_factor_weights.shape[1]))])

# %%
init_weight = np.ones(daily_factor_weights.shape[0]) / daily_factor_weights.shape[0]
hr = np.empty((0,daily_factor_weights.shape[0]))
for i in range(50):
    factor_weights,hr = update_weights_history(history_weights[i-52],r[i-50],hr)

# %%
contest_channel=grpc.insecure_channel('47.103.23.116: 56702')
question_channel=grpc.insecure_channel('47.103.23.116: 56701')

contest_stub=contest_pb2_grpc.ContestStub(contest_channel)
question_stub=question_pb2_grpc.QuestionStub(question_channel)

login_response=contest_stub.login(contest_pb2.LoginRequest(user_id=88,user_pin='dDTSvdwk'))

session_key=login_response.session_key
init_capital=login_response.init_capital

# %%
i=0#控制seq
count=0
data_lst=df.values.tolist()
# factors_lst=[]
period=5#eg 每两天跑一次策略
comission=0#
max_exposure=0.1#大盘上涨，多头增加，大盘下跌，空头增加
single_stock_position_limit=0.1#
lending_rate=0.01#
borrow_rate=0.05#
leverage=2#
# factors=pd.DataFrame()
# prev_factors=pd.DataFrame()#上一次计算的factors
bias=0
# prepare history data
# o 
# h 
# l 
# c 
# v 
# p 
# history_weights = np.ndarray()

# %%
period=1
# lgb_model = joblib.load('./lgb_model3.pkl')
while True:
    login_response=contest_stub.login(contest_pb2.LoginRequest(user_id=88,user_pin='dDTSvdwk'))

    session_key=login_response.session_key
    init_capital=login_response.init_capital
    i = 0
    try:
        while True:
            question_response=question_stub.get_question(question_pb2.QuestionRequest(user_id=88,sequence=i))
            print(question_response.sequence)
            if question_response.sequence!=-1:
                if i == 0 :
                    i = question_response.sequence
                dailystk = [x.values for x in question_response.dailystk]

                daily = np.asarray(dailystk)
                o = np.vstack([o,daily[:,2]])
                h = np.vstack([o,daily[:,3]])
                l = np.vstack([o,daily[:,4]])
                c = np.vstack([o,daily[:,5]])
                v = np.vstack([o,daily[:,6]])
                if count>-1:#开始不动，只要有新数据就跑一次策略
                    print('run strategy')

                    
                    # dailyfactors=get_factors(df,prev_factors)  #从数据获取因子

                    dailyfactors = get_factors_with_ohlcv(o,h,l,c,v,lgb_model,k_model)
                    # prev_factors=dailyfactors

                    daily_factor_weights = get_all_weights(dailyfactors,head_n=10,tail_n=10) # shape: 351 * factors#

                    daily_trade_weights = get_trade_weights(daily_factor_weights,factor_weights,bias=bias) # shape: 351 * 1

                    # factor_select=['avg', 'mom', 'max52', 'D', 'willr', 'natr', 'rsi']

                    # index_direction='neutral'#TODO 大盘方向，用于控制exposure

                    # daily_trade_weights = get_weight(dailyfactors[factor_select],head_n=5,tail_n=5)
                    # factors_lst.extend(dailyfactors.values)#向因子库追加
                    #部份因子可能需要根据历史因子数据归一化

                    # factor_select=select_factors(factors,n=10,period=period)  #计算相关系数选取因子
                    # factor_select=['avg', 'mom', 'max52', 'cci', 'K', 'D', 'J', 'rsi', 'trix', 'willr']
                    # factor_select=['avg','mom', 'vol', 'max52', 'K', 'D', 'J', 'rsi', 'trix', 'willr', 'macd', 'natr','mfi']
                    # factor_select=['avg', 'mom', 'max52', 'D', 'willr', 'natr', 'rsi']

                    # index_direction='neutral'#TODO 大盘方向，用于控制exposure

                    # weights = get_weight(dailyfactors[factor_select],head_n=10,tail_n=10)
                    if count < 10:
                        target_pos=get_position(daily_trade_weights,
                                                pd.DataFrame(dailystk,columns=['day','stock','open','high','low','close','volume'],dtype=float),#只需要close，待优化
                                                question_response.positions,
                                                question_response.capital / 2,
                                                comission)
                    else:
                        target_pos=get_position(daily_trade_weights,
                                                pd.DataFrame(dailystk,columns=['day','stock','open','high','low','close','volume'],dtype=float),#只需要close，待优化
                                                question_response.positions,
                                                question_response.capital,
                                                comission)
                    
                    #提交策略
                    if count%period==0:#按周期提交
                        ##summit answer
                        submit_response = contest_stub.submit_answer(contest_pb2.AnswerRequest(user_id=88,user_pin='dDTSvdwk',session_key=login_response.session_key,sequence=i,positions=target_pos))

                        print(submit_response,question_response.capital)
                        if not submit_response.accepted:
                            print(submit_response.reason)
                            if submit_response.reason[-7:] == 'timeout':
                                i=question_response.sequence+1
                                count+=1
                                continue#如果提交超时，直接请求新数据
                    history_weights = np.vstack([history_weights,daily_factor_weights.reshape((1,daily_factor_weights.shape[0],daily_factor_weights.shape[1]))])
                    pctchg = c[-1,:] / c[-2,:] - 1
                    if np.mean(pctchg)>0:
                        bias = -0.03
                    else:
                        bias = 0.01
                    bias=0.03
                    r = np.vstack([r,pctchg])
                    factor_weights,hr = update_weights_history(history_weights[-3],pctchg,hr)
                    # data_lst.extend(dailystk)
                    # df=pd.DataFrame(data_lst,columns=['day','stock','open','high','low','close','volume'], dtype=float).set_index(['day','stock']).iloc[-351*100:]
                    # df.to_csv('./data/saved_data2.csv')
                i=question_response.sequence+1
                count+=1
            time.sleep(1)
            # if count==20:
                # break
    except Exception as e:
        print(e)
    time.sleep(1)
# Out:
# 006
# 1007.0    -17129
# 1008.0    239084
# 1009.0     25768
#            ...
# 1327.0    281105
# 1329.0     41339
# 1334.0     -2536
# 1339.0    -96001
# 1349.0     61678
# Name: close, Length: 111, dtype: int32
# accepted: true
#  469588337.64114946
# -1
# 1039
# run strategy
# 0.5150000000000001 -0.48500000000000004
# stock
# 1001.0     18380
# 1003.0     42989
# 1004.0      5834
# 1005.0      6927
# 1006.0    172532
#            ...
# 1339.0    -92694
# 1342.0     14526
# 1346.0   -104970
# 1349.0     59564
# 1350.0      5059
# Name: close, Length: 111, dtype: int32
# accepted: true
#  467449083.28937095
# -1
# 1040
# run strategy
# 0.515 -0.48500000000000015
# stock
# 1001.0      9158
# 1003.0     43776
# 1004.0      5958
# 1006.0   -168539
# 1007.0    -17666
#            ...
# 1323.0   -422969
# 1336.0     31971
# 1339.0     49956
# 1342.0    -30547
# 1343.0     19065
# Name: close, Length: 115, dtype: int32
# accepted: true
#  466916118.4801945
# -1
# -1
# 1041
# run strategy
# 0.515 -0.4850000000000001
# stock
# 1002.0     75338
# 1003.0    131904
# 1005.0      7089
# 1006.0    177810
# 1007.0    -17766
#            ...
# 1319.0    -44352
# 1323.0   -422271
# 1342.0     15573
# 1343.0     38039
# 1344.0    -22207
# Name: close, Length: 106, dtype: int32
# accepted: true
#  463905073.9326219
# -1
# 1042
# run strategy
# 0.515 -0.4850000000000001
# stock
# 1001.0      9056
# 1002.0     71647
# 1005.0      6819
# 1007.0    -26215
# 1008.0     46923
#            ...
# 1342.0     15195
# 1343.0     36964
# 1346.0    220883
# 1349.0    132207
# 1350.0      5122
# Name: close, Length: 112, dtype: int32
# accepted: true
#  464242236.49594814
# -1
# 1043
# run strategy
# 0.5149999999999999 -0.48500000000000004
# stock
# 1001.0      9897
# 1002.0     83248
# 1007.0    -28324
# 1008.0    146447
# 1012.0     -7256
#            ...
# 1337.0      6582
# 1342.0     31287
# 1343.0     19264
# 1346.0    117724
# 1350.0      5267
# Name: close, Length: 115, dtype: int32
# accepted: true
#  460034947.31697583
# -1
# -1
# 1044
# run strategy
# 0.515 -0.485
# stock
# 1001.0     20411
# 1002.0     75974
# 1006.0   -161054
# 1007.0    -26853
# 1008.0    185521
#            ...
# 1337.0      6385
# 1342.0     44590
# 1343.0     54908
# 1349.0    -65074
# 1350.0      4905
# Name: close, Length: 108, dtype: int32
# accepted: true
#  459789205.9212614
# -1
# 1045
# run strategy
# 0.515 -0.485
# stock
# 1001.0      9993
# 1002.0     87193
# 1003.0    -47542
# 1007.0     -9763
# 1008.0    148962
#            ...
# 1334.0     -2873
# 1337.0      6771
# 1342.0     31658
# 1343.0     39309
# 1350.0     15167
# Name: close, Length: 108, dtype: int32
# accepted: true
#  459442245.20539683
# -1
# 1046
# run strategy
# 0.5149999999999999 -0.485
# stock
# 1001.0     10844
# 1003.0    -50105
# 1005.0     -7750
# 1006.0   -171520
# 1007.0    -19876
#            ...
# 1337.0      6967
# 1339.0     50182
# 1342.0     31658
# 1343.0     58964
# 1350.0      5300
# Name: close, Length: 107, dtype: int32
# accepted: true
#  459442245.20539683
# -1
# -1
# 1047
# run strategy
# 0.5150000000000001 -0.485
# stock
# 1001.0     10944
# 1003.0   -104148
# 1005.0     -8547
# 1006.0   -211752
# 1008.0    159571
#            ...
# 1330.0    -97255
# 1334.0     -3140
# 1342.0     68704
# 1343.0     61833
# 1350.0      5576
# Name: close, Length: 93, dtype: int32
# accepted: true
#  456442426.4689903
# -1
# 1048
# run strategy
# 0.515 -0.4850000000000001
# stock
# 1001.0     10438
# 1002.0    -98932
# 1003.0   -162581
# 1005.0    -16988
# 1008.0    106755
#            ...
# 1339.0    105614
# 1340.0    -10831
# 1342.0     51431
# 1343.0     63572
# 1350.0     15707
# Name: close, Length: 92, dtype: int32
# accepted: true
#  461916420.81273323
# -1
# -1
# 1049
# run strategy
# 0.515 -0.48500000000000015
# stock
# 1001.0     10065
# 1005.0    -16468
# 1006.0   -181946
# 1008.0     55391
# 1014.0   -250681
#            ...
# 1339.0    103597
# 1340.0    -10469
# 1343.0     40777
# 1347.0     -3317
# 1350.0     20195
# Name: close, Length: 94, dtype: int32
# accepted: true
#  460531227.7761648
# -1
# 1050
# run strategy
# 0.5149999999999999 -0.48500000000000004
# stock
# 1001.0      9498
# 1002.0    -88806
# 1006.0   -173479
# 1013.0    -29756
# 1022.0     -3808
#            ...
# 1340.0    -20487
# 1341.0     -8385
# 1342.0    -14878
# 1343.0     18958
# 1350.0     22173
# Name: close, Length: 94, dtype: int32
# accepted: true
#  460652746.26969856
# -1
# 1051
# run strategy
# 0.5150000000000001 -0.48500000000000004
# stock
# 1001.0      9696
# 1006.0   -174597
# 1013.0    -30312
# 1022.0     -8203
# 1024.0     44566
#            ...
# 1340.0    -21035
# 1341.0     -8459
# 1342.0    -30312
# 1343.0     19152
# 1350.0     26688
# Name: close, Length: 92, dtype: int32
# accepted: true
#  463314413.17870426
# -1
# 1052
# run strategy
# 0.515 -0.4850000000000001
# stock
# 1006.0   -196873
# 1013.0   -103686
# 1022.0     -9331
# 1024.0     47639
# 1025.0     -2474
#            ...
# 1342.0    -48603
# 1343.0     21826
# 1346.0   -125427
# 1347.0      3683
# 1350.0     29144
# Name: close, Length: 90, dtype: int32
# accepted: true
#  463511168.93516463
# -1
# -1
# 1053
# run strategy
# 0.515 -0.48500000000000015
# stock
# 1003.0    -64066
# 1005.0     -9719
# 1006.0   -213145
# 1013.0    -36313
# 1014.0   -306396
#            ...
# 1340.0    -25822
# 1342.0    -51066
# 1343.0     22632
# 1347.0      4302
# 1350.0     16033
# Name: close, Length: 98, dtype: int32
# accepted: true
#  466986665.6472881
# -1
# 1054
# run strategy
# 0.5150000000000001 -0.48500000000000004
# stock
# 1002.0    124960
# 1005.0    -10477
# 1006.0   -209708
# 1008.0    -67647
# 1010.0     96986
#            ...
# 1340.0    -27871
# 1342.0    -72815
# 1343.0     24204
# 1345.0    -30839
# 1350.0     11807
# Name: close, Length: 87, dtype: int32
# accepted: true
#  463736682.10526836
# -1
# 1055
# run strategy
# 0.5150000000000001 -0.48500000000000004
# stock
# 1002.0    117162
# 1003.0   -125777
# 1005.0    -19784
# 1006.0   -203375
# 1015.0    -94481
#            ...
# 1339.0     56006
# 1340.0    -13046
# 1342.0    -49996
# 1346.0   -148137
# 1350.0      5675
# Name: close, Length: 94, dtype: int32
# accepted: true
#  463736682.10526836
# -1
# -1
# 1056
# run strategy
# 0.5150000000000001 -0.48500000000000015
# stock
# 1001.0     16312
# 1002.0   -132441
# 1003.0   -140212
# 1005.0    -22561
# 1006.0   -206112
#            ...
# 1339.0     58040
# 1340.0    -14713
# 1342.0    -37761
# 1346.0   -213220
# 1350.0      6557
# Name: close, Length: 93, dtype: int32
# accepted: true
#  471211871.55616635
# -1
# 1057
# run strategy
# 0.5149999999999999 -0.48500000000000015
# stock
# 1001.0     15871
# 1002.0    119895
# 1003.0   -159563
# 1006.0   -217650
# 1009.0    -44706
#            ...
# 1329.0    119758
# 1339.0     58548
# 1340.0    -17041
# 1342.0    -39384
# 1346.0   -175972
# Name: close, Length: 94, dtype: int32
# accepted: true
#  472710186.18546563
# -1
# -1
# 1058
# run strategy
# 0.5150000000000001 -0.48500000000000004
# stock
# 1003.0   -175481
# 1005.0    -29275
# 1007.0    -17775
# 1009.0    -67782
# 1011.0     -5883
#            ...
# 1327.0   -577691
# 1336.0     62478
# 1339.0     62406
# 1340.0    -19336
# 1342.0    -40346
# Name: close, Length: 92, dtype: int32
# accepted: true
#  484260618.2158242
# -1
# 1059
# run strategy
# 0.5150000000000001 -0.485
# stock
# 1002.0    133466
# 1003.0   -342427
# 1006.0   -531749
# 1008.0    -73669
# 1009.0     54682
#            ...
# 1321.0   -326412
# 1323.0   -757743
# 1342.0    -42096
# 1345.0    -55413
# 1346.0   -208826
# Name: close, Length: 83, dtype: int32
# accepted: true
#  483612100.35026073
# -1
# 1060
# run strategy
# 0.515 -0.48500000000000004
# stock
# 1000.0     -80900
# 1002.0     147979
# 1003.0    -345471
# 1006.0    -228395
# 1008.0     -70476
#            ...
# 1314.0     199561
# 1321.0    -325632
# 1322.0     201480
# 1323.0    1684402
# 1342.0     -39153
# Name: close, Length: 91, dtype: int32
# accepted: true
#  490078699.7820737
# -1
# -1
# 1061
# run strategy
# 0.515 -0.48500000000000015
# stock
# 1003.0    -400697
# 1004.0      15854
# 1006.0    -453657
# 1009.0      58059
# 1014.0    -799135
#            ...
# 1323.0   -1484108
# 1324.0     -10957
# 1334.0      -5803
# 1342.0     -18820
# 1350.0       5193
# Name: close, Length: 90, dtype: int32
# accepted: true
#  480667396.9791457
# -1
# 1062
# run strategy
# 0.5150000000000001 -0.4850000000000001
# stock
# 1000.0   -145655
# 1006.0   -200112
# 1007.0    -14470
# 1009.0     49138
# 1011.0     -5776
#            ...
# 1325.0     18348
# 1337.0    -12839
# 1343.0     20509
# 1346.0   -185104
# 1350.0     17902
# Name: close, Length: 104, dtype: int32
# accepted: true
#  471545963.960656
# -1
# 1063
# run strategy
# 0.5150000000000001 -0.485
# stock
# 1004.0     16195
# 1006.0   -223095
# 1011.0     -6382
# 1014.0   -458939
# 1015.0    -82233
#            ...
# 1325.0     40837
# 1339.0    -69838
# 1343.0     45282
# 1347.0     -4083
# 1350.0     24366
# Name: close, Length: 94, dtype: int32
# accepted: true
#  478707352.0095109
# -1
# -1
# 1064
# run strategy
# 0.5150000000000001 -0.4850000000000001
# stock
# 1004.0      8053
# 1006.0   -221536
# 1011.0     -5766
# 1014.0   -476302
# 1024.0    -50137
#            ...
# 1338.0   -187520
# 1339.0    -68043
# 1342.0    -18900
# 1347.0      4078
# 1350.0     25981
# Name: close, Length: 97, dtype: int32
# accepted: true
#  479641724.11168665
# -1
# 1065
# run strategy
# 0.5149999999999999 -0.485
# stock
# 1006.0   -226994
# 1011.0     -5316
# 1025.0     -2873
# 1038.0    -43652
# 1041.0    -25576
#            ...
# 1339.0     96414
# 1342.0    -18015
# 1343.0     42661
# 1347.0      3856
# 1350.0     15385
# Name: close, Length: 98, dtype: int32
# accepted: true
#  469527378.1181863
# -1
# 1066
# run strategy
# 0.5150000000000001 -0.48500000000000026
# stock
# 1001.0     12686
# 1006.0   -210385
# 1009.0    -39750
# 1011.0     -5357
# 1012.0     -7841
#            ...
# 1327.0    335506
# 1339.0    137390
# 1342.0    -51754
# 1343.0     22124
# 1350.0     14662
# Name: close, Length: 109, dtype: int32
# accepted: true
#  469527378.1181863
# -1
# -1
# 1067
# run strategy
# 0.515 -0.485
# stock
# 1006.0   -660439
# 1011.0     -5767
# 1013.0    -39353
# 1014.0    445474
# 1018.0      4536
#            ...
# 1335.0     34467
# 1336.0     49757
# 1339.0    190789
# 1342.0    -52940
# 1350.0      9350
# Name: close, Length: 103, dtype: int32
# accepted: true
#  472019675.01108533
# -1
# 1068
# run strategy
# 0.5150000000000001 -0.48500000000000004
# stock
# 1001.0     14271
# 1005.0     12285
# 1006.0   -232023
# 1011.0     -6041
# 1012.0      8538
#            ...
# 1335.0     36015
# 1339.0    200086
# 1341.0    -28699
# 1342.0    -55519
# 1343.0    -25209
# Name: close, Length: 104, dtype: int32
# accepted: true
#  475982411.69420284
# -1
# 1069
# run strategy
# 0.5150000000000001 -0.4850000000000001
# stock
# 1004.0      6766
# 1006.0   -440550
# 1011.0    -11367
# 1012.0      8105
# 1014.0    631060
#            ...
# 1339.0    182578
# 1342.0    -52708
# 1345.0     32445
# 1349.0   -108385
# 1350.0      4212
# Name: close, Length: 108, dtype: int32
# accepted: true
#  475982411.69420284
# -1
# -1
# 1070
# run strategy
# 0.515 -0.485
# stock
# 1004.0      7095
# 1006.0   -439729
# 1008.0    -59963
# 1009.0     41548
# 1011.0    -12879
#            ...
# 1332.0    394302
# 1334.0     -4651
# 1339.0     97084
# 1342.0    -36644
# 1350.0      4625
# Name: close, Length: 96, dtype: int32
# accepted: true
#  477518652.25497794
# -1
# 1071
# run strategy
# 0.5149999999999999 -0.4850000000000001
# stock
# 1004.0      6707
# 1006.0   -442509
# 1009.0     39683
# 1011.0     -6117
# 1012.0      8141
#            ...
# 1342.0    -35295
# 1343.0    -44921
# 1344.0     34219
# 1345.0     36048
# 1350.0      4514
# Name: close, Length: 104, dtype: int32
# accepted: true
#  478099066.1759246
# -1
# -1
# 1072
# run strategy
# 0.5149999999999999 -0.48500000000000015
# stock
# 1004.0      6539
# 1006.0   -450886
# 1009.0     37428
# 1011.0     -6202
# 1012.0     16261
#            ...
# 1339.0     95755
# 1342.0    -35247
# 1343.0    -22206
# 1344.0     33071
# 1350.0      4739
# Name: close, Length: 107, dtype: int32
# accepted: true
#  477455431.1909178
# -1
# 1073
# run strategy
# 0.515 -0.48499999999999993
# stock
# 1005.0     11884
# 1006.0   -654998
# 1009.0     33095
# 1011.0     -5659
# 1012.0     15748
#            ...
# 1339.0    139102
# 1340.0    -15007
# 1342.0    -34136
# 1344.0     31325
# 1350.0      4391
# Name: close, Length: 110, dtype: int32
# accepted: true
#  474102551.7042983
# -1
# 1074
# run strategy
# 0.515 -0.48500000000000004
# stock
# 1001.0     11665
# 1003.0     88357
# 1006.0    198860
# 1011.0    -11351
# 1012.0      8268
#            ...
# 1340.0    -30327
# 1342.0    -52838
# 1347.0      3696
# 1348.0      5929
# 1350.0      4684
# Name: close, Length: 107, dtype: int32
# accepted: true
#  471116876.193709
# -1
# -1
# 1075
# run strategy
# 0.515 -0.485
# stock
# 1003.0     86793
# 1005.0     10679
# 1006.0    194534
# 1011.0     -5964
# 1012.0      8088
#            ...
# 1339.0     92672
# 1340.0    -14448
# 1342.0    -51689
# 1344.0     30695
# 1348.0      5787
# Name: close, Length: 113, dtype: int32
# accepted: true
#  472684088.2283823
# -1
# 1076
# run strategy
# 0.5150000000000001 -0.48499999999999993
# stock
# 1003.0     75167
# 1005.0      9739
# 1006.0    154972
# 1009.0     27228
# 1011.0     -5196
#            ...
# 1339.0     85690
# 1340.0    -12494
# 1342.0    -32663
# 1343.0    -20174
# 1347.0      3310
# Name: close, Length: 122, dtype: int32
# accepted: true
#  470455916.5383264
# -1
# 1077
# run strategy
# 0.515 -0.4850000000000001
# stock
# 1005.0     20076
# 1006.0    172981
# 1008.0     60880
# 1011.0     -5416
# 1012.0     -7120
#            ...
# 1326.0    -43818
# 1339.0     91917
# 1342.0    -35037
# 1343.0    -22639
# 1347.0      3396
# Name: close, Length: 106, dtype: int32
# accepted: true
#  468599053.6004809
# -1
# -1
# 1078
# run strategy
# 0.5149999999999999 -0.48500000000000004
# stock
# 1006.0   -157429
# 1007.0    -12508
# 1011.0     -5595
# 1012.0     -6787
# 1013.0     35172
#            ...
# 1339.0     86206
# 1342.0    -32860
# 1343.0     21982
# 1344.0     29586
# 1347.0      3174
# Name: close, Length: 114, dtype: int32
# accepted: true
#  462018053.7907806
# -1
# 1079
# run strategy
# 0.515 -0.48500000000000004
# stock
# 1006.0   -163400
# 1008.0    106146
# 1009.0     27340
# 1010.0     99585
# 1011.0     -5582
#            ...
# 1342.0    -33717
# 1343.0     22113
# 1347.0      9269
# 1348.0      5027
# 1350.0     -3662
# Name: close, Length: 108, dtype: int32
# accepted: true
#  462508119.2951436
# -1
# -1
# 1080
# run strategy
# 0.515 -0.4850000000000002
# stock
# 1006.0   -165079
# 1009.0     26268
# 1010.0     97801
# 1011.0     -5365
# 1014.0    729207
#            ...
# 1325.0     15176
# 1338.0    125207
# 1342.0    -34063
# 1347.0      3232
# 1348.0      4976
# Name: close, Length: 110, dtype: int32
# accepted: true
#  461418146.6188498
# -1
# 1081
# run strategy
# 0.515 -0.485
# stock
# 1003.0     81336
# 1006.0   -161784
# 1009.0     51980
# 1010.0     96087
# 1011.0     -5266
#            ...
# 1342.0    -33897
# 1343.0     20067
# 1347.0      3085
# 1348.0      4870
# 1350.0      3985
# Name: close, Length: 107, dtype: int32
# accepted: true
#  464979233.8664122
# -1
# 1082
# run strategy
# 0.515 -0.4850000000000001
# stock
# 1003.0     89934
# 1006.0   -182518
# 1010.0     98130
# 1014.0   -339569
# 1015.0     38126
#            ...
# 1339.0    123488
# 1342.0    -17382
# 1347.0      9365
# 1348.0     10038
# 1350.0      4058
# Name: close, Length: 110, dtype: int32
# accepted: true
#  464959917.3460065
# -1
# -1
# 1083
# run strategy
# 0.5150000000000001 -0.48499999999999993
# stock
# 1006.0   -171851
# 1014.0    328465
# 1015.0     36847
# 1018.0      2209
# 1021.0     21773
#            ...
# 1339.0     40337
# 1343.0     21094
# 1347.0      3160
# 1348.0      4916
# 1350.0      4120
# Name: close, Length: 108, dtype: int32
# accepted: true
#  465566887.4516367
# -1
# 1084
# run strategy
# 0.5149999999999999 -0.4850000000000002
# stock
# 1006.0   -171083
# 1008.0     53968
# 1009.0     28136
# 1013.0     35223
# 1014.0    329593
#            ...
# 1329.0     62524
# 1339.0     40834
# 1343.0     41570
# 1347.0      6051
# 1348.0      4957
# Name: close, Length: 117, dtype: int32
# accepted: true
#  467164853.47665226
# -1
# 1085
# run strategy
# 0.515 -0.485
# stock
# 1003.0     73388
# 1005.0      8792
# 1006.0   -167023
# 1013.0     33254
# 1018.0      2066
#            ...
# 1323.0    380046
# 1339.0     75336
# 1343.0     19002
# 1347.0      2876
# 1348.0      4562
# Name: close, Length: 113, dtype: int32
# accepted: true
#  469126862.4781785
# -1
# -1
# 1086
# run strategy
# 0.5150000000000001 -0.485
# stock
# 1003.0     75139
# 1005.0      9051
# 1006.0   -178392
# 1008.0    102462
# 1015.0     68412
#            ...
# 1339.0     79094
# 1342.0    -16848
# 1343.0     19948
# 1347.0      5912
# 1348.0      4721
# Name: close, Length: 108, dtype: int32
# accepted: true
#  467994560.6285411
# -1
# 1087
# run strategy
# 0.5149999999999999 -0.4850000000000001
# stock
# 1005.0      9719
# 1006.0   -609483
# 1007.0     12410
# 1008.0    104922
# 1010.0    -89642
#            ...
# 1339.0     80992
# 1342.0    -34505
# 1343.0    -19068
# 1347.0      3119
# 1348.0      9816
# Name: close, Length: 113, dtype: int32
# accepted: true
#  467394696.3934458
# -1
# 1088
# run strategy
# 0.5150000000000001 -0.485
# stock
# 1006.0   -368365
# 1007.0     11395
# 1008.0     98676
# 1011.0      4668
# 1014.0    358824
#            ...
# 1335.0    -28593
# 1339.0    115268
# 1342.0    -32451
# 1347.0      5789
# 1348.0     18292
# Name: close, Length: 113, dtype: int32
# accepted: true
#  467394696.3934458
# -1
# -1
# 1089
# run strategy
# 0.5149999999999999 -0.4850000000000001
# stock
# 1003.0     74319
# 1004.0      6124
# 1006.0   -398783
# 1010.0     85385
# 1011.0      4977
#            ...
# 1339.0     82090
# 1342.0    -34972
# 1343.0    -19672
# 1347.0      3226
# 1348.0     14734
# Name: close, Length: 103, dtype: int32
# accepted: true
#  461734833.8259592
# -1
# 1090
# run strategy
# 0.5149999999999999 -0.48499999999999993
# stock
# 1004.0      6117
# 1006.0   -199295
# 1008.0     49528
# 1010.0     84649
# 1012.0     -7307
#            ...
# 1339.0    123602
# 1342.0    -34797
# 1347.0      5893
# 1348.0      9709
# 1350.0      4142
# Name: close, Length: 107, dtype: int32
# accepted: true
#  459423240.2608008
# -1
# -1
# 1091
# run strategy
# 0.5149999999999999 -0.48500000000000004
# stock
# 1002.0    116929
# 1008.0     49246
# 1009.0    -56008
# 1010.0     83103
# 1011.0      5063
#            ...
# 1339.0     81645
# 1342.0    -34783
# 1343.0    -20479
# 1347.0      5909
# 1348.0      4703
# Name: close, Length: 114, dtype: int32
# accepted: true
#  465197746.9888344
# -1
# 1092
# run strategy
# 0.515 -0.48500000000000015
# stock
# 1003.0     79318
# 1008.0     49227
# 1010.0    162948
# 1011.0      5184
# 1013.0     34135
#            ...
# 1342.0    -34953
# 1343.0    -20389
# 1346.0    162382
# 1347.0      8040
# 1348.0      9159
# Name: close, Length: 108, dtype: int32
# accepted: true
#  467480494.58865285
# -1
# 1093
# run strategy
# 0.515 -0.48500000000000004
# stock
# 1008.0    98395
# 1009.0   -27169
# 1010.0    82285
# 1011.0     5305
# 1013.0    66294
#           ...
# 1339.0    81283
# 1342.0   -17328
# 1347.0     2701
# 1348.0     9560
# 1350.0    17082
# Name: close, Length: 110, dtype: int32
# accepted: true
#  467197409.4244173
# -1
# -1
# 1094
# run strategy
# 0.5150000000000002 -0.485
# stock
# 1008.0     90418
# 1012.0     -6776
# 1013.0     31746
# 1016.0    -12480
# 1018.0     -1960
#            ...
# 1323.0   -962366
# 1324.0     -8598
# 1339.0     37219
# 1347.0      2524
# 1350.0      6875
# Name: close, Length: 110, dtype: int32
# accepted: true
#  464781583.22463626
# -1
# 1095
# run strategy
# 0.515 -0.485
# stock
# 1004.0      5651
# 1008.0     92736
# 1009.0     26476
# 1014.0    355122
# 1016.0    -12461
#            ...
# 1330.0     53587
# 1342.0    -16590
# 1346.0   -151578
# 1347.0      4944
# 1350.0      6883
# Name: close, Length: 110, dtype: int32
# accepted: true
#  464484132.6664869
# -1
# 1096
# run strategy
# 0.5150000000000001 -0.48500000000000015
# stock
# 1004.0      6116
# 1008.0    100488
# 1014.0   -368024
# 1024.0     49486
# 1025.0     -3050
#            ...
# 1333.0     12873
# 1339.0     42084
# 1343.0    -21077
# 1347.0      2750
# 1350.0     11106
# Name: close, Length: 98, dtype: int32
# accepted: true
#  466961056.09509146
# -1
# -1
# 1097
# run strategy
# 0.5150000000000001 -0.48500000000000004
# stock
# 1000.0    -62329
# 1004.0      6131
# 1008.0    234042
# 1014.0   -367347
# 1017.0      9343
#            ...
# 1342.0     38397
# 1343.0    -21039
# 1346.0   -172708
# 1347.0      2753
# 1350.0     11324
# Name: close, Length: 107, dtype: int32
# accepted: true
#  466102822.98109096
# -1
# 1098
# run strategy
# 0.515 -0.485
# stock
# 1003.0    -90864
# 1004.0     19019
# 1008.0    144617
# 1014.0   -363875
# 1023.0     57518
#            ...
# 1345.0    -38149
# 1346.0   -173969
# 1347.0      5671
# 1348.0      5075
# 1350.0      7335
# Name: close, Length: 103, dtype: int32
# accepted: true
#  467044936.55128217
# -1
# 1099
# run strategy
# 0.5150000000000002 -0.485
# stock
# 1002.0   -128561
# 1003.0   -184078
# 1004.0     19219
# 1008.0     49834
# 1011.0     -6057
#            ...
# 1339.0     44249
# 1342.0     20050
# 1343.0    -21972
# 1347.0      2891
# 1350.0      3752
# Name: close, Length: 102, dtype: int32
# accepted: true
#  467044936.55128217
# -1
# -1
# -1
# -1
# -1
# -1
# <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "Stream removed"
# 	debug_error_string = "{"created":"@1609183622.615000000","description":"Error received from peer ipv4:47.103.23.116:56701","file":"src/core/lib/surface/call.cc","file_line":1055,"grpc_message":"Stream removed","grpc_status":2}"
# >
# ---------------------------------------------------------------------------
# _Rendezvous                               Traceback (most recent call last)
# <ipython-input-43-3a28aea8e73a> in <module>
#       2 # lgb_model = joblib.load('./lgb_model3.pkl')
#       3 while True:
# ----> 4     login_response=contest_stub.login(contest_pb2.LoginRequest(user_id=88,user_pin='dDTSvdwk'))
#       5
#       6     session_key=login_response.session_key
#
# D:\Anaconda3\envs\inno\lib\site-packages\grpc\_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     688         state, call, = self._blocking(request, timeout, metadata, credentials,
#     689                                       wait_for_ready, compression)
# --> 690         return _end_unary_response_blocking(state, call, False, None)
#     691
#     692     def with_call(self,
#
# D:\Anaconda3\envs\inno\lib\site-packages\grpc\_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     590             return state.response
#     591     else:
# --> 592         raise _Rendezvous(state, None, None, deadline)
#     593
#     594
#
# _Rendezvous: <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1609183625.686000000","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3934,"referenced_errors":[{"created":"@1609183625.686000000","description":"failed to connect to all addresses","file":"src/core/ext/filters/client_channel/lb_policy/pick_first/pick_first.cc","file_line":393,"grpc_status":14}]}"
# >

# %%
pd.DataFrame(data_lst,columns=['day','stock','open','high','low','close','volume'], dtype=float).set_index(['day','stock']).to_csv('./data/saved_data3.csv')

# %%
daily_factor_weights.shape
# Out:
# (14, 351)

# %%
history_weights
# Out:
# array([-0., -0., -0., ..., -0., -0., -0.])
